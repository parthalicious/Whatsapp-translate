# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install OpenNMT-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.2/227.2 KB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.5/31.5 MB 36.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 93.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 63.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 KB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 KB 12.7 MB/s eta 0:00:00
# ...

# %%
# %%writefile myconfig.yaml
#
# save_data: /content/drive/MyDrive/thesis/
# # Vocabulary files that were just created
# src_vocab: /content/drive/MyDrive/thesis/vocab/src.wh
# tgt_vocab: /content/drive/MyDrive/thesis/vocab/tgt.en
# overwrite: True
#
# # Corpus opts:
# data:
#     corpus_1:
#         path_src: /content/drive/MyDrive/thesis/whatsappsrc1.txt
#         path_tgt: /content/drive/MyDrive/thesis/whatsappengtgt1.txt
#
#
#     valid:
#         path_src: /content/drive/MyDrive/thesis/whatsappsrcval1.txt
#         path_tgt: /content/drive/MyDrive/thesis/whatsappengtgtval1.txt
# Out:
# Overwriting myconfig.yaml

# %%
! onmt_build_vocab -config myconfig.yaml -n_sample 2000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-03-30 20:20:37,511 INFO] Counter vocab from 2000 samples.
# [2023-03-30 20:20:37,511 INFO] Build vocab on 2000 transformed examples/corpus.
# [2023-03-30 20:20:37,623 INFO] Counters src: 7386
# [2023-03-30 20:20:37,623 INFO] Counters tgt: 7722

# %%
#english dataset
#! head -n 5 /content/drive/MyDrive/NLP_Project/Dataset1/train.en
# Out:
# iron cement is a ready for use paste which is laid as a fillet by putty knife or finger in the mould edges ( corners ) of the steel ingot mould .
# iron cement protects the ingot against the hot , abrasive steel casting process .
# a fire restant repair cement for fire places , ovens , open fireplaces etc .
# Construction and repair of highways and ...
# An announcement must be commercial character .

# %%
#german dataset
#! head -n 5 /content/drive/MyDrive/NLP_Project/Dataset1/train.de
# Out:
# iron cement ist eine gebrauchs ##AT##-##AT## fertige Paste , die mit einem Spachtel oder den Fingern als Hohlkehle in die Formecken ( Winkel ) der Stahlguss -Kokille aufgetragen wird .
# Nach der Aushärtung schützt iron cement die Kokille gegen den heissen , abrasiven Stahlguss .
# feuerfester Reparaturkitt für Feuerungsanlagen , Öfen , offene Feuerstellen etc.
# Der Bau und die Reparatur der Autostraßen ...
# die Mitteilungen sollen den geschäftlichen kommerziellen Charakter tragen .

# %%
#!wc -l /content/drive/MyDrive/NLP_Project/Dataset1/newstest2015.en
# Out:
# 2169 /content/drive/MyDrive/NLP_Project/Dataset1/newstest2015.en

# %%
# %%writefile myconfig.yaml
#
# # Vocabulary files that were just created
# src_vocab: /content/drive/MyDrive/thesis/vocab/src.wh
# tgt_vocab: /content/drive/MyDrive/thesis/vocab/tgt.en
# overwrite: False
#
# # Corpus opts:
# data:
#     corpus_1:
#         path_src: /content/drive/MyDrive/thesis/whatsappsrc1.txt
#         path_tgt: /content/drive/MyDrive/thesis/whatsappengtgt1.txt
#
#
#     valid:
#         path_src: /content/drive/MyDrive/thesis/whatsappsrcval1.txt
#         path_tgt: /content/drive/MyDrive/thesis/whatsappengtgtval1.txt
# # Train on a single GPU
# world_size: 1
# gpu_ranks: [0]
#
# # Where to save the checkpoints
# save_model: /content/drive/MyDrive/thesis/whtoen/
# save_checkpoint_steps: 500
# train_steps: 40000
# valid_steps: 500
# Out:
# Overwriting myconfig.yaml

# %%
# !onmt_train -config myconfig.yaml
# Out:
# [2023-03-30 20:22:54,203 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2023-03-30 20:22:54,203 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-03-30 20:22:54,203 INFO] Missing transforms field for valid data, set to default: [].
# [2023-03-30 20:22:54,204 INFO] Parsed 2 corpora from -data.
# [2023-03-30 20:22:54,204 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2023-03-30 20:22:54,249 INFO] Building model...
# [2023-03-30 20:22:56,953 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(7392, 500, padding_idx=1)
#         )
#       )
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (rnn): LSTM(500, 500, num_layers=2, batch_first=True, dropout=0.3)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
# ...

# %%
  #training from the 20500 epoch
#  !onmt_train -config myconfig.yaml  -train_from /content/drive/MyDrive/thesis/whtoen/_step_95000.pt
# Out:
# [2022-11-11 09:34:24,677 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2022-11-11 09:34:24,678 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-11-11 09:34:24,678 INFO] Missing transforms field for valid data, set to default: [].
# [2022-11-11 09:34:24,679 INFO] Parsed 2 corpora from -data.
# [2022-11-11 09:34:24,680 INFO] Loading checkpoint from /content/drive/MyDrive/NLP_Project/_step_95000.pt
# Traceback (most recent call last):
#   File "/usr/local/bin/onmt_train", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/onmt/bin/train.py", line 65, in main
#     train(opt)
#   File "/usr/local/lib/python3.7/dist-packages/onmt/bin/train.py", line 50, in train
#     train_process(opt, device_id=0)
#   File "/usr/local/lib/python3.7/dist-packages/onmt/train_single.py", line 131, in main
#     checkpoint, vocabs, transforms_cls = _init_train(opt)
# ...

# %%
# %%writefile input.txt
# How are you
# I am doing work for company
# The file cabinet drawers are open.
# He is expected to come home soon.
# Out:
# Writing input.txt

# %%
# !onmt_translate -model /content/drive/MyDrive/thesis/whtoen/_step_40000.pt -src /content/drive/MyDrive/thesis/whatsapp.txt -output /content/drive/MyDrive/thesis/output_en.txt -gpu 0 -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# SENT 26036: ['unhonne', 'kaha', '"main', 'apane', 'paise', 'ke', 'lie', 'bahut', 'kadee', '<unk>', 'karata', 'hoon,', 'main', 'aapako', 'kabhee', 'bhee', 'ek', 'paisa', 'barbaad', 'nahin', 'karane', 'ja', 'raha', '<unk>', '<unk>', 'mein', 'motar', '<unk>', 'kee', 'sankhya', 'laakhon', 'hone', 'ka', 'anumaan', 'hai', 'jo', 'ek', 'din', 'mein', 'tan', '<unk>', 'aur', 'dhuen', 'ka', 'utsarjan', 'karate', 'hain']
# PRED 26036: he said “ i wish very hard to <unk> my money i never have to <unk> a money <unk> ” the number of <unk> <unk> <unk> out of a day <unk> <unk> which <unk> the tons of <unk> and smoke in a day
# PRED SCORE: -0.2854
#
# [2023-03-30 22:10:26,850 INFO]
# SENT 26037: ['<unk>', 'mein', 'motar', '<unk>', 'kee', 'sankhya', 'laakhon', 'hone', 'ka', 'anumaan', 'hai', 'jo', 'ek', 'din', 'mein', 'kaee', 'tan', '<unk>', 'aur', '<unk>', 'chhodate', 'hain']
# ...
