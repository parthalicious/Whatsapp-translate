# %%
# !wget https://data.deepai.org/WMT2014EngGer.zip --no-check-certificate

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/WMT2014EngGer.zip" -d "/content/DataSet"

# %%
! pip install OpenNMT-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.2/227.2 KB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 KB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 KB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 60.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.5/31.5 MB 10.6 MB/s eta 0:00:00
# ...

# %%
# f = open("/content/drive/MyDrive/NLP_Project/Dataset1/train_60k.de", "a")

# with open(r"/content/drive/MyDrive/NLP_Project/Dataset1/train.de", 'r') as fp:
#     for i, line in enumerate(fp):
#         if i < 60000:
#             f.write(line)
#         if i > 60000:
#             break
# f.close()

# %%
# %%writefile myconfig.yaml
#
# save_data: /content/drive/MyDrive/thesis/
# # Vocabulary files that were just created
# src_vocab: /content/drive/MyDrive/thesis/transformer/vocab/src.wh
# tgt_vocab: /content/drive/MyDrive/thesis/transformer/vocab/tgt.en
# overwrite: True
#
# # Corpus opts:
# data:
#     corpus_1:
#         path_src: /content/drive/MyDrive/thesis/whatsappsrc1.txt
#         path_tgt: /content/drive/MyDrive/thesis/whatsappengtgt1.txt
#
#
#     valid:
#         path_src: /content/drive/MyDrive/thesis/whatsappsrcval1.txt
#         path_tgt: /content/drive/MyDrive/thesis/whatsappengtgtval1.txt
#
#
#
# # data: exp/dataset.de-en
# save_model: /content/drive/MyDrive/thesis/transformer/whtoen/
# save_checkpoint_steps: 500
# keep_checkpoint: 10
# seed: 3435
# train_steps: 60000
# valid_steps: 500
# warmup_steps: 8000
# report_every: 100
#
# decoder_type: transformer
# encoder_type: transformer
# word_vec_size: 512
# hidden_size: 512
# layers: 6
# transformer_ff: 2048
# heads: 8
#
# accum_count: 8
# optim: adam
# adam_beta1: 0.9
# adam_beta2: 0.998
# decay_method: noam
# learning_rate: 2.0
# max_grad_norm: 0.0
#
# batch_size: 4096
# batch_type: tokens
# normalization: tokens
# dropout: 0.1
# label_smoothing: 0.1
#
# max_generator_batches: 2
#
# param_init: 0.0
# param_init_glorot: 'true'
# position_encoding: 'true'
#
# world_size: 1
# gpu_ranks: [0]
# Out:
# Overwriting myconfig.yaml

# %%
! onmt_build_vocab -config myconfig.yaml -n_sample 2000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-03-31 05:49:29,849 INFO] Counter vocab from 2000 samples.
# [2023-03-31 05:49:29,849 INFO] Build vocab on 2000 transformed examples/corpus.
# [2023-03-31 05:49:30,003 INFO] Counters src: 7386
# [2023-03-31 05:49:30,004 INFO] Counters tgt: 7722
# [2023-03-31 05:49:30,004 WARNING] path /content/drive/MyDrive/thesis/transformer/vocab/src.wh exists, may overwrite...
# [2023-03-31 05:49:30,019 WARNING] path /content/drive/MyDrive/thesis/transformer/vocab/tgt.en exists, may overwrite...

# %%
! head -n 5 /content/drive/MyDrive/thesis/whatsappsrc1.txt
# Out:
# main aapako aise hee ek baal raajaneetigy ke baare mein bataana chaahata hoon, jise karane kee anumati nahin hai
# yah pratishat bhaarat mein pratishat se bhee adhik hai aaeedee aapako aise hee ek bachche ke baare mein bataana chaahata hoon
# in vedon ke antim bhaag ko upanishad kaha jaata hai, hamaara vaastav mein matalab yah hai ki ve dhyaan na dene mein bure hain
# in vedon ke antim bhaag ko upanishad kaha jaata hai
# isamen aapake saamane logon kee paristhitiyaan nihit hain aur ham yah kahane vaale kaun hote hain ki ve galat hain

# %%
! head -n 5 /content/drive/MyDrive/thesis/whatsappengtgt1.txt
# Out:
# id like to tell you about one such child politicians do not have permission to do what needs to be done
# this percentage is even greater than the percentage in india id like to tell you about one such child
# the ending portion of these vedas is called upanishad what we really mean is that theyre bad at not paying attention
# the ending portion of these vedas is called upanishad
# in this lies the circumstances of people before you and who are we to say even that they are wrong

# %%
#english dataset
! head -n 5 /content/drive/MyDrive/thesis/transformer/vocab/src.wh
# Out:
# ke	2624
# mein	1745
# aur	1641
# hai	1406
# kee	1227

# %%
#german dataset
! head -n 5 /content/drive/MyDrive/thesis/transformer/vocab/tgt.en
# Out:
# the	3308
# of	1996
# and	1606
# to	1315
# in	1220

# %%
# !wc -l /content/drive/MyDrive/thesis/whatsappengtgt1.txt
# Out:
# 19999 /content/drive/MyDrive/thesis/whatsappengtgt1.txt

# %%
# %%writefile myconfig.yaml

# # Vocabulary files that were just created
# src_vocab: /content/drive/MyDrive/NLP_Project/Save_Data/Vocab/vocab_en1.en
# tgt_vocab: /content/drive/MyDrive/NLP_Project/Save_Data/Vocab/vocab_de1.de
# overwrite: False

# # Corpus opts:
# data:
#     corpus_1:
#         path_src: /content/drive/MyDrive/NLP_Project/Dataset1/train.en
#         path_tgt: /content/drive/MyDrive/NLP_Project/Dataset1/train.de
    

#     valid:
#         path_src: /content/drive/MyDrive/NLP_Project/Dataset1/newstest2013.en
#         path_tgt: /content/drive/MyDrive/NLP_Project/Dataset1/newstest2013.de
# # Train on a single GPU
# world_size: 1
# gpu_ranks: [0]

# # Where to save the checkpoints
# save_model: /content/drive/MyDrive/NLP_Project/EngToGer_SavePoints/
# save_checkpoint_steps: 1000
# train_steps: 40000
# valid_steps: 1000

# %%
# !onmt_train -config myconfig.yaml
# Out:
# [2023-03-31 05:49:40,890 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2023-03-31 05:49:40,891 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-03-31 05:49:40,891 INFO] Missing transforms field for valid data, set to default: [].
# [2023-03-31 05:49:40,892 INFO] Parsed 2 corpora from -data.
# [2023-03-31 05:49:40,892 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2023-03-31 05:49:40,938 INFO] Building model...
# [2023-03-31 05:49:41,933 INFO] NMTModel(
#   (encoder): TransformerEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(7392, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding()
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
# ...

# %%
# !onmt_translate -model /content/drive/MyDrive/thesis/transformer/whtoen/_step_3000.pt -src /content/drive/MyDrive/thesis/whatsapp.txt -output /content/drive/MyDrive/thesis/transformer/output_en.txt -gpu 0 -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# SENT 1998: None
# PRED 1998: Ein <unk> an der <unk> : &quot; Sie <unk> sich nicht länger als ein <unk> , dass Sie keine <unk> &quot; <unk> &quot; <unk> können .
# PRED SCORE: -0.7398
#
# [2022-11-22 10:30:08,175 INFO]
# SENT 1999: None
# PRED 1999: <unk> <unk> : <unk> dieser Welt ist das <unk> <unk> ?
# PRED SCORE: -0.5250
#
# [2022-11-22 10:30:08,175 INFO]
# SENT 2000: None
# PRED 2000: Die <unk> besteht aus fünf Millionen <unk> , einer der größten <unk> Europas .
# PRED SCORE: -0.7943
#
# [2022-11-22 10:30:08,175 INFO]
# SENT 2001: None
# PRED 2001: <unk> das <unk> <unk> des Landes sind <unk> für die <unk> <unk> .
# PRED SCORE: -0.7606
#
# [2022-11-22 10:30:08,176 INFO]
# SENT 2002: None
# PRED 2002: Wir bieten eine Auswahl an <unk> ##AT##-##AT## <unk> .
# PRED SCORE: -0.3672
#
# [2022-11-22 10:30:08,176 INFO]
# SENT 2003: None
# PRED 2003: <unk> sie sich am <unk> des <unk> <unk> , <unk> <unk> .
# PRED SCORE: -0.6661
#
# ...
